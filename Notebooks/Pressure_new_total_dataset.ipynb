# %% [markdown]
# <a href="https://colab.research.google.com/github/acse-srm3018/DeeplearningProxy/blob/main/Notebooks/Pressure_new_total_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Jul 23 19:30:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-077a8409-285c-40ec-aa78-035051ca5c92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-077a8409-285c-40ec-aa78-035051ca5c92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving unet_uae.py to unet_uae.py
# {'unet_uae.py': b'"""Path hack to make tests work."""\r\nfrom layers import *\r\nfrom keras import backend as K\r\nfrom keras.layers import Input, Flatten, Dense, Lambda, Reshape\r\nfrom keras.layers import concatenate, TimeDistributed, RepeatVector, ConvLSTM2D\r\nfrom keras.models import Model\r\nimport numpy as np\r\n\r\n\r\ndef create_vae(input_shape, depth):\r\n    """\r\n    Create VAE to create something new.\r\n\r\n    Parameters:\r\n    -------\r\n    input_shape : Tuple\r\n    depth : int\r\n    Returns:\r\n    -------\r\n    encoder: encoder\r\n    model : recurrnet R-UNET model\r\n\r\n    """\r\n    # Encoder\r\n    input = Input(shape=input_shape, name=\'image\')\r\n\r\n    enc1 = conv_bn_relu(16, 3, 3, stride=(2, 2))(input)\r\n    time_enc1 = RepeatConv(depth)(enc1)\r\n    enc2 = conv_bn_relu(32, 3, 3, stride=(1, 1))(enc1)\r\n    time_enc2 = RepeatConv(depth)(enc2)\r\n    enc3 = conv_bn_relu(64, 3, 3, stride=(2, 2))(enc2)\r\n    time_enc3 = RepeatConv(depth)(enc3)\r\n    enc4 = conv_bn_relu(128, 3, 3, stride=(1, 1))(enc3)\r\n    time_enc4 = RepeatConv(depth)(enc4)\r\n\r\n    x = res_conv(128, 3, 3)(enc4)\r\n    x = res_conv(128, 3, 3)(x)\r\n    x = res_conv(128, 3, 3)(x)\r\n\r\n    encoder = Model(input, x, name=\'encoder\')\r\n\r\n    x = RepeatConv(depth)(enc4)\r\n    x = ConvLSTM2D(128, (3, 3), strides=(1, 1),\r\n                   padding=\'same\', activation=\'relu\',\r\n                   return_sequences=True)(x)\r\n    # x = ConvLSTM2D(64, (3, 3), strides=(1, 1), padding = \'same\',\r\n    # activation=\'relu\', return_sequences = True)(x)\r\n    # x = ConvLSTM2D(128, (3, 3), strides=(1, 1), padding = \'same\',\r\n    # activation=\'relu\', return_sequences = True)(x)\r\n    x = time_res_conv(128, 3, 3)(x)\r\n    x = time_res_conv(128, 3, 3)(x)\r\n    dec4 = time_res_conv(128, 3, 3)(x)\r\n\r\n    merge4 = concatenate([time_enc4, dec4], axis=4)\r\n    dec3 = time_dconv_bn_nolinear(128, 3, 3, stride=(1, 1))(merge4)\r\n    merge3 = concatenate([time_enc3, dec3], axis=4)\r\n    dec2 = time_dconv_bn_nolinear(64, 3, 3, stride=(2, 2))(merge3)\r\n    merge2 = concatenate([time_enc2, dec2], axis=4)\r\n    dec1 = time_dconv_bn_nolinear(32, 3, 3, stride=(1, 1))(merge2)\r\n    merge1 = concatenate([time_enc1, dec1], axis=4)\r\n    dec0 = time_dconv_bn_nolinear(16, 3, 3, stride=(2, 2))(merge1)\r\n\r\n    output = TimeDistributed(Conv2D(1, (3, 3), padding=\'same\',\r\n                                    activation=None))(dec0)\r\n    print(\'output shape is \', K.int_shape(output))\r\n    # Full net\r\n    full_model = Model(input, output)\r\n\r\n    return full_model, encoder\r\n'}

# %%
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import unet_uae as vae_util
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
from tensorflow.keras import layers
from tensorflow.keras.models import load_model, Model
from tensorflow.python.keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf 
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.3
sess = tf.compat.v1.Session(config=config)
K.set_session(sess)

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
def load_data(path):
    """
    Function to load datasets in format .NPY
    
    Parameter:
    ----------
    path : string
        The absolute path of where data saved in local system
        
    Return:
    ----------
    loaded_data : ndarray
        The data which was loaded
    """
    loaded_data = np.load(path)
    return loaded_data

# %%
# Two common methods for feature scaling is : 1-Normalization & 2-Standardaisation

def normalize(data):
    """
    this function used for Max-Min Normalization (Min-Max scaling) by re-scaling
    features with a distribution value between 0 and 1. For every feature,the minimum
    value of that feature gets transformed into 0, and the maximum value 
    gets transformed into 1
    
    Parameter:
    ----------
    data : ndarray
        The numpy array which we want to normalize
        
    Return:
    ----------
    norm_data : ndarray
        The normalized data which transformed into 0 and 1
    """
    max_p = np.max(data[:, :, :, :])
    min_p = np.min(data[:, :, :, :])
    norm_data = (data - min_p)/(max_p - min_p)
    return norm_data

def standardize(data):
    """
    this function used for rescaling faetures to ensure the mean
    and the standard deviation to be 0 and 1, respectively.
    
    Parameter:
    ----------
    data : ndarray
        The numpy array which we want to normalize
        
    Return:
    ----------
    data : ndarray
        The standardized data which the mean
    and the standard deviation to be 0 and 1
    """
    data_mean = np.mean(data[:, :, :, :], axis = 0, keepdims = True)
    data_std = np.std(data[:, :, :, :], axis = 0, keepdims = True)
    std_data = (data - data_mean)/(data_std)
    return std_data

# %%
# define the absolute path of training datatsat
path_perm = '/content/gdrive/MyDrive/perm.npy'
path_press = '/content/gdrive/MyDrive/pressure.npy'
# use load_data function nd above path to loading data
X_data= load_data(path_perm)
target_data = load_data(path_press)

# %%
# Normalize data using abov normalize function
train_nr = 2250
test_nr = 750

# %%
p_t_mean = np.mean(target_data[:train_nr, ...], axis = 0, keepdims = True)
target_data = target_data - p_t_mean
print('max p is ', np.max(target_data[:train_nr, ...]), ', min p is ', np.min(target_data[:train_nr, ...]))
max_p = np.max(target_data[:train_nr, ...])
min_p = np.min(target_data[:train_nr, ...])
target_data = (target_data - min_p)/(max_p -min_p) - 0.5
print('max p is ', np.max(target_data), ', min p is ', np.min(target_data))
print('max p train is ', np.max(target_data[:train_nr, ...]), ', min p train is ', np.min(target_data[:train_nr, ...]))
# Out:
# max p is  0.7920798934504856 , min p is  -0.20792010654951504
# max p is  0.5039995270719007 , min p is  -0.500166926837037
# max p train is  0.5 , min p train is  -0.5

# %%
input_shape=(100, 100, 2)
depth = 10
vae_model,_ = vae_util.create_vae(input_shape, depth)
vae_model.summary()
# Out:
# output shape is  (None, 10, 100, 100, 1)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 100, 100, 2) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 50, 50, 16)   304         image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 50, 50, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 50, 50, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 50, 32)   4640        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 50, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 50, 50, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 25, 25, 64)   18496       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 25, 25, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 25, 25, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 128)  73856       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 25, 25, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# repeat_conv_4 (RepeatConv)      (None, 10, 25, 25, 1 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)       (None, 10, 25, 25, 1 1180160     repeat_conv_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 10, 25, 25, 1 147584      conv_lst_m2d[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 10, 25, 25, 1 512         time_distributed_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 25, 25, 1 0           conv_lst_m2d[0][0]
#                                                                  time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 10, 25, 25, 1 147584      add_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 10, 25, 25, 1 512         time_distributed_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 10, 25, 25, 1 0           add_3[0][0]
#                                                                  time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 10, 25, 25, 1 147584      add_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 10, 25, 25, 1 512         time_distributed_13[0][0]
# __________________________________________________________________________________________________
# repeat_conv_3 (RepeatConv)      (None, 10, 25, 25, 1 0           activation_3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 10, 25, 25, 1 0           add_4[0][0]
#                                                                  time_distributed_14[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 25, 25, 2 0           repeat_conv_3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 10, 25, 25, 2 0           concatenate[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 10, 27, 27, 2 0           time_distributed_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 10, 25, 25, 1 295040      time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 10, 25, 25, 1 512         time_distributed_17[0][0]
# __________________________________________________________________________________________________
# repeat_conv_2 (RepeatConv)      (None, 10, 25, 25, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 10, 25, 25, 1 0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 25, 25, 1 0           repeat_conv_2[0][0]
#                                                                  time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 10, 50, 50, 1 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 10, 52, 52, 1 0           time_distributed_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 10, 50, 50, 6 110656      time_distributed_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 10, 50, 50, 6 256         time_distributed_22[0][0]
# __________________________________________________________________________________________________
# repeat_conv_1 (RepeatConv)      (None, 10, 50, 50, 3 0           activation_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 10, 50, 50, 6 0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 10, 50, 50, 9 0           repeat_conv_1[0][0]
#                                                                  time_distributed_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 10, 50, 50, 9 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 10, 52, 52, 9 0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 10, 50, 50, 3 27680       time_distributed_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 10, 50, 50, 3 128         time_distributed_27[0][0]
# __________________________________________________________________________________________________
# repeat_conv (RepeatConv)        (None, 10, 50, 50, 1 0           activation[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 10, 50, 50, 3 0           time_distributed_28[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 10, 50, 50, 4 0           repeat_conv[0][0]
#                                                                  time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 10, 100, 100, 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 10, 102, 102, 0           time_distributed_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 10, 100, 100, 6928        time_distributed_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 10, 100, 100, 64          time_distributed_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 10, 100, 100, 0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 10, 100, 100, 145         time_distributed_34[0][0]
# ==================================================================================================
# Total params: 2,164,113
# Trainable params: 2,162,385
# Non-trainable params: 1,728
# __________________________________________________________________________________________________

# %%
depth = 10
nr = X_data.shape[0]
train_nr = 2250
test_nr = 750
train_x = np.concatenate([X_data[:train_nr,[0], ...],target_data[:train_nr,[0], ...]], axis = 1)
train_y = target_data[:train_nr, ...]

test_x = np.concatenate([X_data[nr-test_nr:,[0], ...], target_data[nr-test_nr:, [0], ...]], axis = 1)
test_y = target_data[nr-test_nr:,...]


train_x = train_x.transpose(0,2,3,1)
train_y = train_y[:,:,:,:,None]
test_x = test_x.transpose(0,2,3,1)
test_y = test_y[:,:,:,:,None]
#test_y = test_y.transpose(0,2,3,1)
print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape is ', test_x.shape)
print('test_y shape is ', test_y.shape)
# Out:
# train_x shape is  (2250, 100, 100, 2)
# train_y shape is  (2250, 10, 100, 100, 1)
# test_x shape is  (750, 100, 100, 2)
# test_y shape is  (750, 10, 100, 100, 1)

# %%
output_dir = '/content/gdrive/MyDrive/Colab Notebooks/saved_models/'
epochs = 300
batch_size = 8
num_batch = int(train_nr/batch_size)

# %%
def vae_loss(x, t_decoded):
    '''Total loss for the plain UAE'''
    return K.mean(reconstruction_loss(x, t_decoded))


def reconstruction_loss(x, t_decoded):
    '''Reconstruction loss for the plain UAE'''

    return K.sum((K.batch_flatten(x) - K.batch_flatten(t_decoded)) ** 2, axis=-1)

def relative_error(x, t_decoded):
    return K.mean(K.abs(x - t_decoded) / x)

# %%
opt = Adam(learning_rate=3e-3)
vae_model.compile(loss = vae_loss, optimizer = opt, metrics = [relative_error])

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
lrScheduler = ReduceLROnPlateau(monitor = 'loss', factor = 0.5, patience = 15, cooldown = 1, verbose = 1, min_lr = 1e-6)
filePath = 'saved-model-{epoch:03d}-{val_loss:.2f}.h5'
checkPoint = ModelCheckpoint(filePath, monitor = 'val_loss', verbose = 1, save_best_only = False, \
                             save_weights_only = True, mode = 'auto', save_freq = 20)

callbacks_list = [lrScheduler, checkPoint]

# %%
history = vae_model.fit(train_x, train_y, batch_size = batch_size, epochs = epochs, \
                        verbose = 1, validation_data = (test_x, test_y))
# Out:
# Epoch 1/300
# 282/282 [==============================] - 88s 144ms/step - loss: 3158.9929 - relative_error: -0.2876 - val_loss: 871.6996 - val_relative_error: -0.3037
# Epoch 2/300
# 282/282 [==============================] - 36s 128ms/step - loss: 121.2886 - relative_error: -0.0912 - val_loss: 1248.3882 - val_relative_error: -0.3763
# Epoch 3/300
# 282/282 [==============================] - 36s 127ms/step - loss: 90.3399 - relative_error: -0.0763 - val_loss: 376.8946 - val_relative_error: -0.2010
# Epoch 4/300
# 282/282 [==============================] - 36s 127ms/step - loss: 83.3401 - relative_error: -0.0732 - val_loss: 326.9743 - val_relative_error: -0.1763
# Epoch 5/300
# 282/282 [==============================] - 35s 126ms/step - loss: 76.4984 - relative_error: -0.0713 - val_loss: 86.3541 - val_relative_error: -0.0776
# Epoch 6/300
# 282/282 [==============================] - 35s 125ms/step - loss: 65.2377 - relative_error: -0.0660 - val_loss: 88.9553 - val_relative_error: -0.0849
# Epoch 7/300
# 282/282 [==============================] - 36s 126ms/step - loss: 69.6296 - relative_error: -0.0661 - val_loss: 66.6675 - val_relative_error: -0.0663
# Epoch 8/300
# 282/282 [==============================] - 36s 128ms/step - loss: 62.8223 - relative_error: -0.0633 - val_loss: 60.0463 - val_relative_error: -0.0659
# Epoch 9/300
# 282/282 [==============================] - 36s 129ms/step - loss: 64.0928 - relative_error: -0.0619 - val_loss: 63.0981 - val_relative_error: -0.0635
# Epoch 10/300
# 282/282 [==============================] - 35s 125ms/step - loss: 50.2373 - relative_error: -0.0577 - val_loss: 50.5789 - val_relative_error: -0.0597
# Epoch 11/300
# 282/282 [==============================] - 36s 127ms/step - loss: 62.5872 - relative_error: -0.0635 - val_loss: 104.1364 - val_relative_error: -0.0932
# Epoch 12/300
# 282/282 [==============================] - 36s 128ms/step - loss: 50.6113 - relative_error: -0.0576 - val_loss: 77.4018 - val_relative_error: -0.0763
# Epoch 13/300
# 282/282 [==============================] - 36s 126ms/step - loss: 50.8172 - relative_error: -0.0576 - val_loss: 173.7595 - val_relative_error: -0.1202
# Epoch 14/300
# 282/282 [==============================] - 36s 127ms/step - loss: 56.9017 - relative_error: -0.0607 - val_loss: 99.4001 - val_relative_error: -0.0947
# Epoch 15/300
# 282/282 [==============================] - 36s 128ms/step - loss: 51.3215 - relative_error: -0.0570 - val_loss: 50.2366 - val_relative_error: -0.0603
# Epoch 16/300
# 282/282 [==============================] - 36s 128ms/step - loss: 46.0844 - relative_error: -0.0546 - val_loss: 98.8134 - val_relative_error: -0.0840
# Epoch 17/300
# 282/282 [==============================] - 35s 126ms/step - loss: 42.8145 - relative_error: -0.0539 - val_loss: 71.5300 - val_relative_error: -0.0646
# Epoch 18/300
# 282/282 [==============================] - 36s 126ms/step - loss: 37.7161 - relative_error: -0.0501 - val_loss: 54.5177 - val_relative_error: -0.0618
# Epoch 19/300
# 282/282 [==============================] - 36s 127ms/step - loss: 38.9772 - relative_error: -0.0511 - val_loss: 47.8523 - val_relative_error: -0.0591
# Epoch 20/300
# 282/282 [==============================] - 36s 127ms/step - loss: 36.0100 - relative_error: -0.0487 - val_loss: 71.6003 - val_relative_error: -0.0715
# Epoch 21/300
# 282/282 [==============================] - 35s 126ms/step - loss: 33.7230 - relative_error: -0.0472 - val_loss: 106.8984 - val_relative_error: -0.0942
# Epoch 22/300
# 282/282 [==============================] - 36s 127ms/step - loss: 32.8352 - relative_error: -0.0469 - val_loss: 36.0636 - val_relative_error: -0.0511
# Epoch 23/300
# 282/282 [==============================] - 35s 125ms/step - loss: 30.7171 - relative_error: -0.0457 - val_loss: 36.5860 - val_relative_error: -0.0497
# Epoch 24/300
# 282/282 [==============================] - 36s 128ms/step - loss: 27.9860 - relative_error: -0.0438 - val_loss: 41.6847 - val_relative_error: -0.0539
# Epoch 25/300
# 282/282 [==============================] - 36s 126ms/step - loss: 26.9690 - relative_error: -0.0423 - val_loss: 57.8998 - val_relative_error: -0.0621
# Epoch 26/300
# 282/282 [==============================] - 36s 127ms/step - loss: 30.3218 - relative_error: -0.0444 - val_loss: 58.6042 - val_relative_error: -0.0646
# Epoch 27/300
# 282/282 [==============================] - 36s 127ms/step - loss: 26.3000 - relative_error: -0.0402 - val_loss: 151.3784 - val_relative_error: -0.1217
# Epoch 28/300
# 282/282 [==============================] - 36s 128ms/step - loss: 17.6865 - relative_error: -0.0330 - val_loss: 168.5122 - val_relative_error: -0.1287
# Epoch 29/300
# 282/282 [==============================] - 36s 126ms/step - loss: 16.5612 - relative_error: -0.0323 - val_loss: 18.9670 - val_relative_error: -0.0382
# Epoch 30/300
# 282/282 [==============================] - 36s 128ms/step - loss: 12.9625 - relative_error: -0.0288 - val_loss: 46.7018 - val_relative_error: -0.0582
# Epoch 31/300
# 282/282 [==============================] - 36s 126ms/step - loss: 13.1183 - relative_error: -0.0283 - val_loss: 57.8508 - val_relative_error: -0.0559
# Epoch 32/300
# 282/282 [==============================] - 36s 127ms/step - loss: 15.9453 - relative_error: -0.0322 - val_loss: 87.2010 - val_relative_error: -0.0837
# Epoch 33/300
# 282/282 [==============================] - 36s 128ms/step - loss: 11.0772 - relative_error: -0.0266 - val_loss: 124.8672 - val_relative_error: -0.1078
# Epoch 34/300
# 282/282 [==============================] - 36s 128ms/step - loss: 11.5767 - relative_error: -0.0271 - val_loss: 60.7147 - val_relative_error: -0.0690
# Epoch 35/300
# 282/282 [==============================] - 35s 125ms/step - loss: 12.4791 - relative_error: -0.0280 - val_loss: 43.4378 - val_relative_error: -0.0585
# Epoch 36/300
# 282/282 [==============================] - 36s 128ms/step - loss: 10.4453 - relative_error: -0.0257 - val_loss: 29.4146 - val_relative_error: -0.0427
# Epoch 37/300
# 282/282 [==============================] - 36s 127ms/step - loss: 10.5681 - relative_error: -0.0257 - val_loss: 49.5086 - val_relative_error: -0.0593
# Epoch 38/300
# 282/282 [==============================] - 36s 128ms/step - loss: 9.6567 - relative_error: -0.0245 - val_loss: 106.7556 - val_relative_error: -0.0944
# Epoch 39/300
# 282/282 [==============================] - 38s 136ms/step - loss: 11.5375 - relative_error: -0.0270 - val_loss: 38.0608 - val_relative_error: -0.0526
# Epoch 40/300
# 282/282 [==============================] - 36s 128ms/step - loss: 9.8468 - relative_error: -0.0252 - val_loss: 43.8739 - val_relative_error: -0.0581
# Epoch 41/300
# 282/282 [==============================] - 36s 127ms/step - loss: 7.8820 - relative_error: -0.0223 - val_loss: 29.1928 - val_relative_error: -0.0466
# Epoch 42/300
# 282/282 [==============================] - 36s 129ms/step - loss: 9.0927 - relative_error: -0.0241 - val_loss: 18.8758 - val_relative_error: -0.0372
# Epoch 43/300
# 282/282 [==============================] - 36s 127ms/step - loss: 10.0707 - relative_error: -0.0255 - val_loss: 53.3460 - val_relative_error: -0.0681
# Epoch 44/300
# 282/282 [==============================] - 36s 128ms/step - loss: 8.4390 - relative_error: -0.0231 - val_loss: 41.4208 - val_relative_error: -0.0558
# Epoch 45/300
# 282/282 [==============================] - 36s 127ms/step - loss: 7.3516 - relative_error: -0.0219 - val_loss: 26.5862 - val_relative_error: -0.0434
# Epoch 46/300
# 282/282 [==============================] - 36s 128ms/step - loss: 7.3790 - relative_error: -0.0215 - val_loss: 28.3383 - val_relative_error: -0.0480
# Epoch 47/300
# 282/282 [==============================] - 35s 125ms/step - loss: 7.4826 - relative_error: -0.0218 - val_loss: 51.1283 - val_relative_error: -0.0616
# Epoch 48/300
# 282/282 [==============================] - 36s 127ms/step - loss: 7.0044 - relative_error: -0.0212 - val_loss: 30.5262 - val_relative_error: -0.0482
# Epoch 49/300
# 282/282 [==============================] - 36s 127ms/step - loss: 7.4658 - relative_error: -0.0217 - val_loss: 65.6373 - val_relative_error: -0.0714
# Epoch 50/300
# 282/282 [==============================] - 36s 128ms/step - loss: 7.7790 - relative_error: -0.0220 - val_loss: 92.3492 - val_relative_error: -0.0887
# Epoch 51/300
# 282/282 [==============================] - 36s 128ms/step - loss: 7.3174 - relative_error: -0.0215 - val_loss: 29.4145 - val_relative_error: -0.0489
# Epoch 52/300
# 282/282 [==============================] - 36s 127ms/step - loss: 5.9903 - relative_error: -0.0196 - val_loss: 30.7442 - val_relative_error: -0.0486
# Epoch 53/300
# 282/282 [==============================] - 36s 126ms/step - loss: 7.0525 - relative_error: -0.0210 - val_loss: 12.5568 - val_relative_error: -0.0300
# Epoch 54/300
# 282/282 [==============================] - 36s 127ms/step - loss: 10.7407 - relative_error: -0.0260 - val_loss: 10.8476 - val_relative_error: -0.0267
# Epoch 55/300
# 282/282 [==============================] - 36s 126ms/step - loss: 6.6854 - relative_error: -0.0207 - val_loss: 33.1421 - val_relative_error: -0.0484
# Epoch 56/300
# 282/282 [==============================] - 36s 127ms/step - loss: 5.5458 - relative_error: -0.0185 - val_loss: 32.6436 - val_relative_error: -0.0446
# Epoch 57/300
# 282/282 [==============================] - 36s 127ms/step - loss: 6.9152 - relative_error: -0.0209 - val_loss: 50.9951 - val_relative_error: -0.0658
# Epoch 58/300
# 282/282 [==============================] - 36s 126ms/step - loss: 6.5559 - relative_error: -0.0202 - val_loss: 12.1829 - val_relative_error: -0.0314
# Epoch 59/300
# 282/282 [==============================] - 36s 127ms/step - loss: 5.7650 - relative_error: -0.0192 - val_loss: 21.7322 - val_relative_error: -0.0410
# Epoch 60/300
# 282/282 [==============================] - 35s 125ms/step - loss: 5.0106 - relative_error: -0.0177 - val_loss: 18.4337 - val_relative_error: -0.0366
# Epoch 61/300
# 282/282 [==============================] - 36s 126ms/step - loss: 5.3553 - relative_error: -0.0185 - val_loss: 85.5422 - val_relative_error: -0.0834
# Epoch 62/300
# 282/282 [==============================] - 35s 126ms/step - loss: 7.7993 - relative_error: -0.0220 - val_loss: 9.5232 - val_relative_error: -0.0252
# Epoch 63/300
# 282/282 [==============================] - 36s 126ms/step - loss: 4.2765 - relative_error: -0.0164 - val_loss: 38.2773 - val_relative_error: -0.0537
# Epoch 64/300
# 282/282 [==============================] - 36s 126ms/step - loss: 4.6152 - relative_error: -0.0170 - val_loss: 5.7855 - val_relative_error: -0.0193
# Epoch 65/300
# 282/282 [==============================] - 35s 126ms/step - loss: 4.8654 - relative_error: -0.0175 - val_loss: 7.2882 - val_relative_error: -0.0207
# Epoch 66/300
# 282/282 [==============================] - 35s 126ms/step - loss: 5.5416 - relative_error: -0.0186 - val_loss: 16.1602 - val_relative_error: -0.0330
# Epoch 67/300
# 282/282 [==============================] - 36s 126ms/step - loss: 4.3416 - relative_error: -0.0165 - val_loss: 16.9810 - val_relative_error: -0.0294
# Epoch 68/300
# 282/282 [==============================] - 35s 125ms/step - loss: 6.1139 - relative_error: -0.0194 - val_loss: 57.1217 - val_relative_error: -0.0682
# Epoch 69/300
# 282/282 [==============================] - 36s 126ms/step - loss: 4.3351 - relative_error: -0.0163 - val_loss: 37.1875 - val_relative_error: -0.0506
# Epoch 70/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.6508 - relative_error: -0.0149 - val_loss: 38.3575 - val_relative_error: -0.0557
# Epoch 71/300
# 282/282 [==============================] - 35s 126ms/step - loss: 4.1802 - relative_error: -0.0161 - val_loss: 3.8798 - val_relative_error: -0.0152
# Epoch 72/300
# 282/282 [==============================] - 35s 124ms/step - loss: 3.5986 - relative_error: -0.0148 - val_loss: 44.7673 - val_relative_error: -0.0613
# Epoch 73/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.8949 - relative_error: -0.0155 - val_loss: 38.4224 - val_relative_error: -0.0570
# Epoch 74/300
# 282/282 [==============================] - 35s 125ms/step - loss: 5.4418 - relative_error: -0.0183 - val_loss: 36.2150 - val_relative_error: -0.0543
# Epoch 75/300
# 282/282 [==============================] - 35s 126ms/step - loss: 4.5685 - relative_error: -0.0169 - val_loss: 14.5525 - val_relative_error: -0.0331
# Epoch 76/300
# 282/282 [==============================] - 35s 125ms/step - loss: 4.3183 - relative_error: -0.0164 - val_loss: 13.9637 - val_relative_error: -0.0318
# Epoch 77/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.5877 - relative_error: -0.0148 - val_loss: 4.4755 - val_relative_error: -0.0155
# Epoch 78/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.2285 - relative_error: -0.0140 - val_loss: 21.5569 - val_relative_error: -0.0391
# Epoch 79/300
# 282/282 [==============================] - 36s 126ms/step - loss: 3.5648 - relative_error: -0.0149 - val_loss: 4.9376 - val_relative_error: -0.0166
# Epoch 80/300
# 282/282 [==============================] - 35s 125ms/step - loss: 5.3511 - relative_error: -0.0169 - val_loss: 78.5160 - val_relative_error: -0.0832
# Epoch 81/300
# 282/282 [==============================] - 36s 127ms/step - loss: 6.8310 - relative_error: -0.0203 - val_loss: 5.4395 - val_relative_error: -0.0179
# Epoch 82/300
# 282/282 [==============================] - 35s 125ms/step - loss: 4.8440 - relative_error: -0.0173 - val_loss: 7.6400 - val_relative_error: -0.0244
# Epoch 83/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.5997 - relative_error: -0.0146 - val_loss: 5.7785 - val_relative_error: -0.0190
# Epoch 84/300
# 282/282 [==============================] - 37s 133ms/step - loss: 3.3813 - relative_error: -0.0142 - val_loss: 10.8520 - val_relative_error: -0.0274
# Epoch 85/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.1790 - relative_error: -0.0138 - val_loss: 18.1322 - val_relative_error: -0.0400
# Epoch 86/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.2925 - relative_error: -0.0140 - val_loss: 4.2957 - val_relative_error: -0.0159
# Epoch 87/300
# 282/282 [==============================] - 36s 126ms/step - loss: 3.4295 - relative_error: -0.0144 - val_loss: 6.1508 - val_relative_error: -0.0198
# Epoch 88/300
# 282/282 [==============================] - 36s 127ms/step - loss: 4.3152 - relative_error: -0.0163 - val_loss: 9.1595 - val_relative_error: -0.0256
# Epoch 89/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.9109 - relative_error: -0.0132 - val_loss: 34.5458 - val_relative_error: -0.0571
# Epoch 90/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.1504 - relative_error: -0.0138 - val_loss: 39.3876 - val_relative_error: -0.0556
# Epoch 91/300
# 282/282 [==============================] - 36s 126ms/step - loss: 3.7997 - relative_error: -0.0152 - val_loss: 9.6086 - val_relative_error: -0.0263
# Epoch 92/300
# 282/282 [==============================] - 36s 126ms/step - loss: 4.0047 - relative_error: -0.0155 - val_loss: 7.7951 - val_relative_error: -0.0226
# Epoch 93/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.9943 - relative_error: -0.0131 - val_loss: 5.0756 - val_relative_error: -0.0178
# Epoch 94/300
# 282/282 [==============================] - 36s 128ms/step - loss: 3.0709 - relative_error: -0.0135 - val_loss: 2.6428 - val_relative_error: -0.0120
# Epoch 95/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.4453 - relative_error: -0.0144 - val_loss: 3.8006 - val_relative_error: -0.0144
# Epoch 96/300
# 282/282 [==============================] - 36s 128ms/step - loss: 3.5973 - relative_error: -0.0149 - val_loss: 26.4872 - val_relative_error: -0.0462
# Epoch 97/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.7214 - relative_error: -0.0150 - val_loss: 4.3867 - val_relative_error: -0.0170
# Epoch 98/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.0393 - relative_error: -0.0134 - val_loss: 30.8403 - val_relative_error: -0.0480
# Epoch 99/300
# 282/282 [==============================] - 36s 126ms/step - loss: 3.8767 - relative_error: -0.0153 - val_loss: 4.2148 - val_relative_error: -0.0151
# Epoch 100/300
# 282/282 [==============================] - 36s 129ms/step - loss: 3.3150 - relative_error: -0.0140 - val_loss: 20.2877 - val_relative_error: -0.0373
# Epoch 101/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.6297 - relative_error: -0.0125 - val_loss: 4.4015 - val_relative_error: -0.0160
# Epoch 102/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.4351 - relative_error: -0.0119 - val_loss: 6.4303 - val_relative_error: -0.0195
# Epoch 103/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.3283 - relative_error: -0.0116 - val_loss: 4.2565 - val_relative_error: -0.0157
# Epoch 104/300
# 282/282 [==============================] - 36s 129ms/step - loss: 2.9033 - relative_error: -0.0133 - val_loss: 8.8181 - val_relative_error: -0.0251
# Epoch 105/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.7736 - relative_error: -0.0129 - val_loss: 66.5669 - val_relative_error: -0.0558
# Epoch 106/300
# 282/282 [==============================] - 36s 128ms/step - loss: 3.4707 - relative_error: -0.0145 - val_loss: 20.9449 - val_relative_error: -0.0424
# Epoch 107/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.6008 - relative_error: -0.0125 - val_loss: 2.8337 - val_relative_error: -0.0127
# Epoch 108/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.4123 - relative_error: -0.0118 - val_loss: 4.8467 - val_relative_error: -0.0180
# Epoch 109/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.5254 - relative_error: -0.0145 - val_loss: 4.5125 - val_relative_error: -0.0161
# Epoch 110/300
# 282/282 [==============================] - 36s 128ms/step - loss: 6.0515 - relative_error: -0.0194 - val_loss: 3.0760 - val_relative_error: -0.0130
# Epoch 111/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.5470 - relative_error: -0.0122 - val_loss: 3.5462 - val_relative_error: -0.0144
# Epoch 112/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.5179 - relative_error: -0.0121 - val_loss: 8.5603 - val_relative_error: -0.0233
# Epoch 113/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.5565 - relative_error: -0.0121 - val_loss: 2.9559 - val_relative_error: -0.0124
# Epoch 114/300
# 282/282 [==============================] - 36s 128ms/step - loss: 3.1708 - relative_error: -0.0137 - val_loss: 4.2887 - val_relative_error: -0.0167
# Epoch 115/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.3111 - relative_error: -0.0115 - val_loss: 15.8103 - val_relative_error: -0.0339
# Epoch 116/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.4764 - relative_error: -0.0120 - val_loss: 4.3629 - val_relative_error: -0.0156
# Epoch 117/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.4287 - relative_error: -0.0118 - val_loss: 6.8221 - val_relative_error: -0.0228
# Epoch 118/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.5404 - relative_error: -0.0122 - val_loss: 3.4741 - val_relative_error: -0.0134
# Epoch 119/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.1050 - relative_error: -0.0109 - val_loss: 3.0658 - val_relative_error: -0.0133
# Epoch 120/300
# 282/282 [==============================] - 36s 129ms/step - loss: 2.3818 - relative_error: -0.0118 - val_loss: 3.2861 - val_relative_error: -0.0136
# Epoch 121/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.4088 - relative_error: -0.0117 - val_loss: 32.2965 - val_relative_error: -0.0523
# Epoch 122/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.1488 - relative_error: -0.0111 - val_loss: 19.4757 - val_relative_error: -0.0369
# Epoch 123/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.8682 - relative_error: -0.0132 - val_loss: 10.8907 - val_relative_error: -0.0280
# Epoch 124/300
# 282/282 [==============================] - 36s 128ms/step - loss: 7.5702 - relative_error: -0.0204 - val_loss: 4.9299 - val_relative_error: -0.0173
# Epoch 125/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.4463 - relative_error: -0.0117 - val_loss: 13.1841 - val_relative_error: -0.0317
# Epoch 126/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.7495 - relative_error: -0.0127 - val_loss: 6.3304 - val_relative_error: -0.0215
# Epoch 127/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.8619 - relative_error: -0.0130 - val_loss: 6.4631 - val_relative_error: -0.0207
# Epoch 128/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.4946 - relative_error: -0.0121 - val_loss: 2.4800 - val_relative_error: -0.0112
# Epoch 129/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.0661 - relative_error: -0.0109 - val_loss: 11.2834 - val_relative_error: -0.0309
# Epoch 130/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.8868 - relative_error: -0.0132 - val_loss: 7.5843 - val_relative_error: -0.0232
# Epoch 131/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.2211 - relative_error: -0.0113 - val_loss: 2.9221 - val_relative_error: -0.0125
# Epoch 132/300
# 282/282 [==============================] - 36s 127ms/step - loss: 4.6777 - relative_error: -0.0160 - val_loss: 6.9047 - val_relative_error: -0.0204
# Epoch 133/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.8908 - relative_error: -0.0101 - val_loss: 4.2140 - val_relative_error: -0.0163
# Epoch 134/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.2686 - relative_error: -0.0114 - val_loss: 7.1815 - val_relative_error: -0.0219
# Epoch 135/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.2658 - relative_error: -0.0114 - val_loss: 6.7383 - val_relative_error: -0.0203
# Epoch 136/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.7050 - relative_error: -0.0126 - val_loss: 16.6969 - val_relative_error: -0.0370
# Epoch 137/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.4025 - relative_error: -0.0117 - val_loss: 24.9646 - val_relative_error: -0.0431
# Epoch 138/300
# 282/282 [==============================] - 36s 127ms/step - loss: 6.2733 - relative_error: -0.0191 - val_loss: 3.0499 - val_relative_error: -0.0131
# Epoch 139/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.8312 - relative_error: -0.0129 - val_loss: 2.7725 - val_relative_error: -0.0121
# Epoch 140/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.3707 - relative_error: -0.0114 - val_loss: 2.7882 - val_relative_error: -0.0120
# Epoch 141/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.3558 - relative_error: -0.0116 - val_loss: 8.3954 - val_relative_error: -0.0239
# Epoch 142/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.3056 - relative_error: -0.0137 - val_loss: 3.7913 - val_relative_error: -0.0153
# Epoch 143/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.9972 - relative_error: -0.0128 - val_loss: 9.9531 - val_relative_error: -0.0258
# Epoch 144/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.9640 - relative_error: -0.0104 - val_loss: 2.2847 - val_relative_error: -0.0105
# Epoch 145/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.2750 - relative_error: -0.0114 - val_loss: 6.5408 - val_relative_error: -0.0186
# Epoch 146/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.0668 - relative_error: -0.0108 - val_loss: 4.9897 - val_relative_error: -0.0164
# Epoch 147/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.7471 - relative_error: -0.0122 - val_loss: 4.5339 - val_relative_error: -0.0171
# Epoch 148/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.9624 - relative_error: -0.0131 - val_loss: 2.3306 - val_relative_error: -0.0109
# Epoch 149/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.1751 - relative_error: -0.0110 - val_loss: 3.2340 - val_relative_error: -0.0132
# Epoch 150/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.0895 - relative_error: -0.0108 - val_loss: 5.0087 - val_relative_error: -0.0173
# Epoch 151/300
# 282/282 [==============================] - 36s 126ms/step - loss: 3.2381 - relative_error: -0.0133 - val_loss: 6.0841 - val_relative_error: -0.0207
# Epoch 152/300
# 282/282 [==============================] - 35s 124ms/step - loss: 2.1326 - relative_error: -0.0108 - val_loss: 4.0733 - val_relative_error: -0.0144
# Epoch 153/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.9442 - relative_error: -0.0103 - val_loss: 3.0367 - val_relative_error: -0.0127
# Epoch 154/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.2917 - relative_error: -0.0114 - val_loss: 13.7289 - val_relative_error: -0.0308
# Epoch 155/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.0991 - relative_error: -0.0108 - val_loss: 2.8017 - val_relative_error: -0.0125
# Epoch 156/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.6430 - relative_error: -0.0125 - val_loss: 5.0474 - val_relative_error: -0.0171
# Epoch 157/300
# 282/282 [==============================] - 36s 128ms/step - loss: 2.5533 - relative_error: -0.0121 - val_loss: 3.4732 - val_relative_error: -0.0140
# Epoch 158/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.2704 - relative_error: -0.0112 - val_loss: 5.9023 - val_relative_error: -0.0198
# Epoch 159/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.0500 - relative_error: -0.0105 - val_loss: 2.9034 - val_relative_error: -0.0129
# Epoch 160/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.1651 - relative_error: -0.0108 - val_loss: 2.9587 - val_relative_error: -0.0120
# Epoch 161/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.7861 - relative_error: -0.0124 - val_loss: 3.5542 - val_relative_error: -0.0129
# Epoch 162/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.8446 - relative_error: -0.0099 - val_loss: 19.3599 - val_relative_error: -0.0426
# Epoch 163/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.5657 - relative_error: -0.0121 - val_loss: 3.4609 - val_relative_error: -0.0144
# Epoch 164/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.2104 - relative_error: -0.0112 - val_loss: 5.5765 - val_relative_error: -0.0184
# Epoch 165/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.8862 - relative_error: -0.0101 - val_loss: 7.2374 - val_relative_error: -0.0220
# Epoch 166/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.4514 - relative_error: -0.0119 - val_loss: 28.8500 - val_relative_error: -0.0500
# Epoch 167/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.3214 - relative_error: -0.0115 - val_loss: 11.6723 - val_relative_error: -0.0295
# Epoch 168/300
# 282/282 [==============================] - 36s 127ms/step - loss: 1.7012 - relative_error: -0.0094 - val_loss: 2.6306 - val_relative_error: -0.0115
# Epoch 169/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.2369 - relative_error: -0.0110 - val_loss: 4.3695 - val_relative_error: -0.0162
# Epoch 170/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.7435 - relative_error: -0.0096 - val_loss: 11.6383 - val_relative_error: -0.0315
# Epoch 171/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.0522 - relative_error: -0.0105 - val_loss: 2.4637 - val_relative_error: -0.0108
# Epoch 172/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.4640 - relative_error: -0.0119 - val_loss: 3.6359 - val_relative_error: -0.0140
# Epoch 173/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.6963 - relative_error: -0.0125 - val_loss: 2.8802 - val_relative_error: -0.0133
# Epoch 174/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.8714 - relative_error: -0.0101 - val_loss: 2.5648 - val_relative_error: -0.0116
# Epoch 175/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.6449 - relative_error: -0.0093 - val_loss: 3.3586 - val_relative_error: -0.0139
# Epoch 176/300
# 282/282 [==============================] - 35s 126ms/step - loss: 4.4285 - relative_error: -0.0162 - val_loss: 6.9782 - val_relative_error: -0.0236
# Epoch 177/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.7166 - relative_error: -0.0125 - val_loss: 4.1410 - val_relative_error: -0.0146
# Epoch 178/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.0338 - relative_error: -0.0105 - val_loss: 2.7014 - val_relative_error: -0.0121
# Epoch 179/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.8927 - relative_error: -0.0101 - val_loss: 5.8805 - val_relative_error: -0.0209
# Epoch 180/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.0761 - relative_error: -0.0108 - val_loss: 2.3944 - val_relative_error: -0.0112
# Epoch 181/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.8520 - relative_error: -0.0100 - val_loss: 2.3596 - val_relative_error: -0.0110
# Epoch 182/300
# 282/282 [==============================] - 36s 128ms/step - loss: 1.9968 - relative_error: -0.0106 - val_loss: 2.5787 - val_relative_error: -0.0113
# Epoch 183/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.3040 - relative_error: -0.0113 - val_loss: 3.4084 - val_relative_error: -0.0142
# Epoch 184/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.0700 - relative_error: -0.0107 - val_loss: 8.7666 - val_relative_error: -0.0261
# Epoch 185/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.8614 - relative_error: -0.0099 - val_loss: 2.6873 - val_relative_error: -0.0116
# Epoch 186/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.3306 - relative_error: -0.0115 - val_loss: 2.8887 - val_relative_error: -0.0122
# Epoch 187/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.7950 - relative_error: -0.0098 - val_loss: 2.2926 - val_relative_error: -0.0109
# Epoch 188/300
# 282/282 [==============================] - 36s 127ms/step - loss: 1.9036 - relative_error: -0.0101 - val_loss: 2.4945 - val_relative_error: -0.0115
# Epoch 189/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.1766 - relative_error: -0.0109 - val_loss: 3.0420 - val_relative_error: -0.0130
# Epoch 190/300
# 282/282 [==============================] - 35s 126ms/step - loss: 20.1089 - relative_error: -0.0320 - val_loss: 41.5168 - val_relative_error: -0.0554
# Epoch 191/300
# 282/282 [==============================] - 35s 124ms/step - loss: 34.8797 - relative_error: -0.0481 - val_loss: 29.4525 - val_relative_error: -0.0458
# Epoch 192/300
# 282/282 [==============================] - 35s 125ms/step - loss: 24.1702 - relative_error: -0.0400 - val_loss: 46.3895 - val_relative_error: -0.0537
# Epoch 193/300
# 282/282 [==============================] - 35s 124ms/step - loss: 20.9324 - relative_error: -0.0376 - val_loss: 36.7239 - val_relative_error: -0.0508
# Epoch 194/300
# 282/282 [==============================] - 35s 126ms/step - loss: 14.8888 - relative_error: -0.0315 - val_loss: 21.5874 - val_relative_error: -0.0401
# Epoch 195/300
# 282/282 [==============================] - 36s 126ms/step - loss: 14.2352 - relative_error: -0.0308 - val_loss: 15.6292 - val_relative_error: -0.0316
# Epoch 196/300
# 282/282 [==============================] - 35s 124ms/step - loss: 10.9438 - relative_error: -0.0267 - val_loss: 11.2413 - val_relative_error: -0.0271
# Epoch 197/300
# 282/282 [==============================] - 36s 126ms/step - loss: 10.9060 - relative_error: -0.0268 - val_loss: 11.6508 - val_relative_error: -0.0267
# Epoch 198/300
# 282/282 [==============================] - 35s 124ms/step - loss: 9.9913 - relative_error: -0.0254 - val_loss: 9.8329 - val_relative_error: -0.0247
# Epoch 199/300
# 282/282 [==============================] - 35s 125ms/step - loss: 8.8122 - relative_error: -0.0238 - val_loss: 7.7879 - val_relative_error: -0.0218
# Epoch 200/300
# 282/282 [==============================] - 35s 124ms/step - loss: 8.3199 - relative_error: -0.0231 - val_loss: 18.6606 - val_relative_error: -0.0353
# Epoch 201/300
# 282/282 [==============================] - 35s 125ms/step - loss: 8.0711 - relative_error: -0.0228 - val_loss: 9.0836 - val_relative_error: -0.0231
# Epoch 202/300
# 282/282 [==============================] - 35s 125ms/step - loss: 7.4666 - relative_error: -0.0218 - val_loss: 9.0927 - val_relative_error: -0.0231
# Epoch 203/300
# 282/282 [==============================] - 35s 126ms/step - loss: 6.7007 - relative_error: -0.0206 - val_loss: 8.1933 - val_relative_error: -0.0232
# Epoch 204/300
# 282/282 [==============================] - 36s 126ms/step - loss: 6.5826 - relative_error: -0.0203 - val_loss: 6.6394 - val_relative_error: -0.0195
# Epoch 205/300
# 282/282 [==============================] - 36s 126ms/step - loss: 5.6460 - relative_error: -0.0186 - val_loss: 5.6820 - val_relative_error: -0.0182
# Epoch 206/300
# 282/282 [==============================] - 35s 124ms/step - loss: 6.0692 - relative_error: -0.0192 - val_loss: 20.5315 - val_relative_error: -0.0399
# Epoch 207/300
# 282/282 [==============================] - 36s 127ms/step - loss: 5.8342 - relative_error: -0.0191 - val_loss: 40.8749 - val_relative_error: -0.0512
# Epoch 208/300
# 282/282 [==============================] - 35s 125ms/step - loss: 6.1989 - relative_error: -0.0197 - val_loss: 11.0369 - val_relative_error: -0.0267
# Epoch 209/300
# 282/282 [==============================] - 36s 127ms/step - loss: 5.4051 - relative_error: -0.0181 - val_loss: 13.9626 - val_relative_error: -0.0300
# Epoch 210/300
# 282/282 [==============================] - 35s 125ms/step - loss: 4.7307 - relative_error: -0.0170 - val_loss: 8.4382 - val_relative_error: -0.0209
# Epoch 211/300
# 282/282 [==============================] - 36s 126ms/step - loss: 5.2089 - relative_error: -0.0178 - val_loss: 9.0489 - val_relative_error: -0.0231
# Epoch 212/300
# 282/282 [==============================] - 35s 125ms/step - loss: 4.0836 - relative_error: -0.0154 - val_loss: 6.2563 - val_relative_error: -0.0194
# Epoch 213/300
# 282/282 [==============================] - 36s 126ms/step - loss: 3.9373 - relative_error: -0.0153 - val_loss: 5.0176 - val_relative_error: -0.0166
# Epoch 214/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.9098 - relative_error: -0.0152 - val_loss: 4.9888 - val_relative_error: -0.0170
# Epoch 215/300
# 282/282 [==============================] - 35s 125ms/step - loss: 4.0243 - relative_error: -0.0154 - val_loss: 9.5717 - val_relative_error: -0.0250
# Epoch 216/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.5340 - relative_error: -0.0143 - val_loss: 6.8984 - val_relative_error: -0.0218
# Epoch 217/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.4693 - relative_error: -0.0141 - val_loss: 11.3098 - val_relative_error: -0.0248
# Epoch 218/300
# 282/282 [==============================] - 35s 124ms/step - loss: 3.2451 - relative_error: -0.0135 - val_loss: 5.2301 - val_relative_error: -0.0171
# Epoch 219/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.5650 - relative_error: -0.0142 - val_loss: 5.4354 - val_relative_error: -0.0175
# Epoch 220/300
# 282/282 [==============================] - 35s 124ms/step - loss: 3.0332 - relative_error: -0.0131 - val_loss: 3.7658 - val_relative_error: -0.0142
# Epoch 221/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.6807 - relative_error: -0.0145 - val_loss: 4.5822 - val_relative_error: -0.0169
# Epoch 222/300
# 282/282 [==============================] - 35s 123ms/step - loss: 4.4258 - relative_error: -0.0162 - val_loss: 3.9530 - val_relative_error: -0.0142
# Epoch 223/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.8023 - relative_error: -0.0125 - val_loss: 4.1688 - val_relative_error: -0.0154
# Epoch 224/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.2912 - relative_error: -0.0139 - val_loss: 4.4748 - val_relative_error: -0.0155
# Epoch 225/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.1522 - relative_error: -0.0131 - val_loss: 19.9761 - val_relative_error: -0.0387
# Epoch 226/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.9947 - relative_error: -0.0128 - val_loss: 6.8258 - val_relative_error: -0.0203
# Epoch 227/300
# 282/282 [==============================] - 35s 124ms/step - loss: 3.5956 - relative_error: -0.0143 - val_loss: 5.4470 - val_relative_error: -0.0176
# Epoch 228/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.3506 - relative_error: -0.0139 - val_loss: 5.4750 - val_relative_error: -0.0166
# Epoch 229/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.5305 - relative_error: -0.0119 - val_loss: 11.6857 - val_relative_error: -0.0284
# Epoch 230/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.7529 - relative_error: -0.0150 - val_loss: 7.0666 - val_relative_error: -0.0223
# Epoch 231/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.4243 - relative_error: -0.0143 - val_loss: 6.5460 - val_relative_error: -0.0199
# Epoch 232/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.3657 - relative_error: -0.0113 - val_loss: 3.7701 - val_relative_error: -0.0141
# Epoch 233/300
# 282/282 [==============================] - 35s 124ms/step - loss: 3.3128 - relative_error: -0.0137 - val_loss: 6.5266 - val_relative_error: -0.0189
# Epoch 234/300
# 282/282 [==============================] - 36s 126ms/step - loss: 4.0351 - relative_error: -0.0150 - val_loss: 4.1888 - val_relative_error: -0.0149
# Epoch 235/300
# 282/282 [==============================] - 35s 124ms/step - loss: 2.3745 - relative_error: -0.0113 - val_loss: 4.1931 - val_relative_error: -0.0148
# Epoch 236/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.4123 - relative_error: -0.0114 - val_loss: 3.4039 - val_relative_error: -0.0136
# Epoch 237/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.5160 - relative_error: -0.0118 - val_loss: 3.6316 - val_relative_error: -0.0130
# Epoch 238/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.3480 - relative_error: -0.0113 - val_loss: 6.0278 - val_relative_error: -0.0187
# Epoch 239/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.2827 - relative_error: -0.0138 - val_loss: 7.9347 - val_relative_error: -0.0220
# Epoch 240/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.4635 - relative_error: -0.0116 - val_loss: 2.9743 - val_relative_error: -0.0120
# Epoch 241/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.3032 - relative_error: -0.0110 - val_loss: 4.6349 - val_relative_error: -0.0168
# Epoch 242/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.0952 - relative_error: -0.0131 - val_loss: 3.8725 - val_relative_error: -0.0138
# Epoch 243/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.1146 - relative_error: -0.0133 - val_loss: 3.0313 - val_relative_error: -0.0121
# Epoch 244/300
# 282/282 [==============================] - 35s 126ms/step - loss: 3.4074 - relative_error: -0.0133 - val_loss: 5.5720 - val_relative_error: -0.0171
# Epoch 245/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.4051 - relative_error: -0.0114 - val_loss: 3.2199 - val_relative_error: -0.0130
# Epoch 246/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.0352 - relative_error: -0.0104 - val_loss: 5.5059 - val_relative_error: -0.0177
# Epoch 247/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.8920 - relative_error: -0.0127 - val_loss: 18.0711 - val_relative_error: -0.0351
# Epoch 248/300
# 282/282 [==============================] - 36s 127ms/step - loss: 3.6767 - relative_error: -0.0147 - val_loss: 4.3640 - val_relative_error: -0.0151
# Epoch 249/300
# 282/282 [==============================] - 35s 124ms/step - loss: 2.1393 - relative_error: -0.0107 - val_loss: 3.7719 - val_relative_error: -0.0142
# Epoch 250/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.2194 - relative_error: -0.0110 - val_loss: 2.9067 - val_relative_error: -0.0122
# Epoch 251/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.1641 - relative_error: -0.0109 - val_loss: 5.1296 - val_relative_error: -0.0187
# Epoch 252/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.7655 - relative_error: -0.0125 - val_loss: 4.0010 - val_relative_error: -0.0145
# Epoch 253/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.5169 - relative_error: -0.0119 - val_loss: 6.6594 - val_relative_error: -0.0205
# Epoch 254/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.9421 - relative_error: -0.0101 - val_loss: 4.7727 - val_relative_error: -0.0175
# Epoch 255/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.3354 - relative_error: -0.0113 - val_loss: 3.0668 - val_relative_error: -0.0127
# Epoch 256/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.4353 - relative_error: -0.0116 - val_loss: 3.5254 - val_relative_error: -0.0133
# Epoch 257/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.3257 - relative_error: -0.0112 - val_loss: 4.9789 - val_relative_error: -0.0164
# Epoch 258/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.4774 - relative_error: -0.0117 - val_loss: 6.4930 - val_relative_error: -0.0193
# Epoch 259/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.4016 - relative_error: -0.0115 - val_loss: 5.2990 - val_relative_error: -0.0179
# Epoch 260/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.0801 - relative_error: -0.0106 - val_loss: 5.7196 - val_relative_error: -0.0188
# Epoch 261/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.0665 - relative_error: -0.0106 - val_loss: 3.1782 - val_relative_error: -0.0130
# Epoch 262/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.7792 - relative_error: -0.0095 - val_loss: 3.4060 - val_relative_error: -0.0136
# Epoch 263/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.1684 - relative_error: -0.0109 - val_loss: 3.0145 - val_relative_error: -0.0122
# Epoch 264/300
# 282/282 [==============================] - 35s 124ms/step - loss: 2.1288 - relative_error: -0.0107 - val_loss: 3.3601 - val_relative_error: -0.0131
# Epoch 265/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.3578 - relative_error: -0.0132 - val_loss: 4.0952 - val_relative_error: -0.0149
# Epoch 266/300
# 282/282 [==============================] - 35s 124ms/step - loss: 2.0290 - relative_error: -0.0104 - val_loss: 2.6720 - val_relative_error: -0.0117
# Epoch 267/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.7438 - relative_error: -0.0094 - val_loss: 3.9978 - val_relative_error: -0.0148
# Epoch 268/300
# 282/282 [==============================] - 35s 124ms/step - loss: 2.6537 - relative_error: -0.0124 - val_loss: 9.1262 - val_relative_error: -0.0249
# Epoch 269/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.1532 - relative_error: -0.0109 - val_loss: 2.9306 - val_relative_error: -0.0121
# Epoch 270/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.9484 - relative_error: -0.0099 - val_loss: 2.9250 - val_relative_error: -0.0122
# Epoch 271/300
# 282/282 [==============================] - 36s 127ms/step - loss: 1.8644 - relative_error: -0.0100 - val_loss: 2.7954 - val_relative_error: -0.0120
# Epoch 272/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.9185 - relative_error: -0.0101 - val_loss: 2.8883 - val_relative_error: -0.0122
# Epoch 273/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.1700 - relative_error: -0.0109 - val_loss: 4.3617 - val_relative_error: -0.0160
# Epoch 274/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.9116 - relative_error: -0.0101 - val_loss: 3.3003 - val_relative_error: -0.0132
# Epoch 275/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.0892 - relative_error: -0.0105 - val_loss: 4.6922 - val_relative_error: -0.0160
# Epoch 276/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.8492 - relative_error: -0.0100 - val_loss: 2.6511 - val_relative_error: -0.0119
# Epoch 277/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.0466 - relative_error: -0.0106 - val_loss: 2.5234 - val_relative_error: -0.0109
# Epoch 278/300
# 282/282 [==============================] - 35s 124ms/step - loss: 1.9016 - relative_error: -0.0099 - val_loss: 4.4277 - val_relative_error: -0.0156
# Epoch 279/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.7621 - relative_error: -0.0125 - val_loss: 4.4352 - val_relative_error: -0.0159
# Epoch 280/300
# 282/282 [==============================] - 36s 127ms/step - loss: 2.0544 - relative_error: -0.0106 - val_loss: 7.3601 - val_relative_error: -0.0211
# Epoch 281/300
# 282/282 [==============================] - 35s 125ms/step - loss: 3.3417 - relative_error: -0.0141 - val_loss: 2.6480 - val_relative_error: -0.0113
# Epoch 282/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.7330 - relative_error: -0.0095 - val_loss: 5.6320 - val_relative_error: -0.0178
# Epoch 283/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.8082 - relative_error: -0.0098 - val_loss: 11.5303 - val_relative_error: -0.0288
# Epoch 284/300
# 282/282 [==============================] - 36s 126ms/step - loss: 2.4233 - relative_error: -0.0111 - val_loss: 8.4399 - val_relative_error: -0.0228
# Epoch 285/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.2387 - relative_error: -0.0110 - val_loss: 9.8639 - val_relative_error: -0.0240
# Epoch 286/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.3034 - relative_error: -0.0112 - val_loss: 5.2186 - val_relative_error: -0.0179
# Epoch 287/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.9212 - relative_error: -0.0101 - val_loss: 3.0556 - val_relative_error: -0.0125
# Epoch 288/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.6825 - relative_error: -0.0093 - val_loss: 2.6144 - val_relative_error: -0.0117
# Epoch 289/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.5966 - relative_error: -0.0089 - val_loss: 3.4458 - val_relative_error: -0.0138
# Epoch 290/300
# 282/282 [==============================] - 36s 127ms/step - loss: 1.8223 - relative_error: -0.0098 - val_loss: 2.6407 - val_relative_error: -0.0111
# Epoch 291/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.1274 - relative_error: -0.0106 - val_loss: 4.8791 - val_relative_error: -0.0167
# Epoch 292/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.6068 - relative_error: -0.0089 - val_loss: 5.2487 - val_relative_error: -0.0172
# Epoch 293/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.8234 - relative_error: -0.0095 - val_loss: 2.6974 - val_relative_error: -0.0111
# Epoch 294/300
# 282/282 [==============================] - 36s 126ms/step - loss: 1.8102 - relative_error: -0.0096 - val_loss: 2.8256 - val_relative_error: -0.0121
# Epoch 295/300
# 282/282 [==============================] - 35s 126ms/step - loss: 2.3879 - relative_error: -0.0110 - val_loss: 3.1058 - val_relative_error: -0.0127
# Epoch 296/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.9900 - relative_error: -0.0105 - val_loss: 9.2931 - val_relative_error: -0.0239
# Epoch 297/300
# 282/282 [==============================] - 35s 126ms/step - loss: 1.7639 - relative_error: -0.0095 - val_loss: 2.7828 - val_relative_error: -0.0119
# Epoch 298/300
# 282/282 [==============================] - 36s 127ms/step - loss: 1.6444 - relative_error: -0.0091 - val_loss: 18.2545 - val_relative_error: -0.0382
# Epoch 299/300
# 282/282 [==============================] - 35s 125ms/step - loss: 2.2749 - relative_error: -0.0113 - val_loss: 7.9167 - val_relative_error: -0.0239
# Epoch 300/300
# 282/282 [==============================] - 35s 125ms/step - loss: 1.7336 - relative_error: -0.0096 - val_loss: 3.1682 - val_relative_error: -0.0129

# %%
import matplotlib.pyplot as plt
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(np.abs(history.history['relative_error']))
plt.plot(np.abs(history.history['val_relative_error']))
plt.title('model relative error')
plt.ylabel('relative error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'relative_error', 'val_loss', 'val_relative_error'])

# %%
vae_model.save('/content/gdrive/MyDrive/pressure_10_points.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
vae_model.load_weights('/content/gdrive/MyDrive/pressure_10_points.h5')

# %%
p_pred_list = []
test_batch_size = 50 
batch_num = int(test_nr / test_batch_size)
for i in range(batch_num):
    pred = vae_model.predict(test_x[i*test_batch_size: (i+1)*test_batch_size, ...])
    p_pred_list.append(pred[:, :, :, :, 0])

p_pred = np.concatenate(p_pred_list, axis = 0)

print(p_pred.shape)
# Out:
# (750, 10, 100, 100)

# %%
p_true = test_y[:,:,:,:,0]
p_pred = p_pred[:,:,:,:]
print(p_true.shape)
# Out:
# (750, 10, 100, 100)

# %%
# convert pressure back to correct range
p_true = ((max_p - min_p) * (p_true)+ min_p)  + p_t_mean[:,:, ...]
p_pred = ((max_p - min_p) * (p_pred) + min_p) + p_t_mean[:,:, ...]
print(p_pred.shape)
# Out:
# (750, 10, 100, 100)

# %%
p_true = p_true.transpose(0,2,3,1)
p_pred = p_pred.transpose(0,2,3,1)
print(p_true.shape)
print(p_pred.shape)
# Out:
# (750, 100, 100, 10)
# (750, 100, 100, 10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.set_cmap('jet')

ind_case = [0, 1, 3]
num_case = len(ind_case)

# %%
for k in ind_case:
    for i_tstep in range(1):
        plt.figure(figsize=(10,7))
        # True permeability
        plt.subplot(3, 1, 1)
        plt.imshow(test_x[k, ::-1, :, 0])
        cbar = plt.colorbar(fraction=0.046)
        cbar.ax.tick_params(labelsize=16)

        plt.tight_layout()
        plt.subplot(3, 1, 2)
        plt.imshow(test_x[k, ::-1, :, 0].reshape((100,100)), vmin=-0.09, vmax=1.07)
        #plt.set_clim([-0.09, 1.07])
        cbar = plt.colorbar(fraction=0.046)
        cbar.ax.tick_params(labelsize=16)
        plt.tight_layout()
        # The difference between True permeability after prediction
        plt.subplot(3, 1, 3)
        plt.imshow(test_x[k, ::-1, :, 0].reshape((100,100)) - test_x[k, ::-1, :, i_tstep])
        cbar = plt.colorbar(fraction=0.046)
        cbar.ax.tick_params(labelsize=16)
        #plt.clim([-0.2, 0.2])
        plt.tight_layout()
        #plt.savefig('ind_case_%d_logk'%(k),bbox_inches='tight')
plt.show()

# %%
for k in ind_case:
    plt.figure(figsize=(50,50))
    for i_tstep in range(depth):
        plt.subplot(3, depth, i_tstep+1)
       
        plt.imshow(p_pred[k, :, :, i_tstep], vmin=4645, vmax=4775)
        plt.colorbar(fraction=0.046)
        plt.subplot(3, depth, i_tstep+1+depth)
        plt.imshow(p_true[k, :, :, i_tstep].reshape((100,100)), vmin=4645, vmax=4775)
        plt.colorbar(fraction=0.046)
        
        plt.subplot(3, depth, i_tstep+1+2*depth)
        plt.imshow(p_true[k, :, :, i_tstep].reshape((100,100)) - p_pred[k, :, :, i_tstep])
        plt.colorbar(fraction=0.046)
        #plt.clim([-0.2, 0.2])
        plt.tight_layout()
plt.show()

# %%
p_relative_error_time = np.mean(np.abs(p_true - p_pred) / (np.max(p_true, axis = (1, 2), keepdims =True) - np.min(p_true, axis = (1, 2), keepdims =True)), axis = (0, 1, 2))

# %%
plt.figure()
plt.plot(p_relative_error_time)
plt.show()
